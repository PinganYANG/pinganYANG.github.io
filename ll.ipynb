# %%
import pandas as pd

# %%
pd.read_csv('Country_Stock_Market_Information.csv',index_col=0)
# Out:
#                  Country (Chinese) Has Stock Market Stock Market Info Link
# Country
# United States                   美国              Yes    https://example.com
# Euro Area                      欧元区               No    https://example.com
# China                           中国              Yes    https://example.com
# Japan                           日本              Yes    https://example.com
# Germany                         德国              Yes    https://example.com
# ...                            ...              ...                    ...
# Papua New Guinea           巴布亚新几内亚               No    https://example.com
# Samoa                          萨摩亚               No    https://example.com
# Solomon Islands              所罗门群岛               No    https://example.com
# Tonga                           汤加               No    https://example.com
# Vanuatu                       瓦努阿图               No    https://example.com
#
# [226 rows x 3 columns]
